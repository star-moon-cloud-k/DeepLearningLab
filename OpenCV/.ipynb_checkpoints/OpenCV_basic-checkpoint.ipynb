# %%
image_data = '/Users/k/Desktop/StudySource/source/sky.JPG'
video_data = '/Users/k/Desktop/StudySource/source/IMG_7874.MOV'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread(image_data, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image);

# %%
image.shape
# Out:
# (1600, 2400)

# %%
image
# Out:
# array([[ 57,  57,  57, ...,  69,  70,  71],
#        [ 57,  56,  57, ...,  70,  70,  71],
#        [ 56,  56,  56, ...,  70,  71,  71],
#        ...,
#        [ 59,  60,  61, ..., 126, 127, 127],
#        [ 60,  61,  61, ..., 127, 128, 129],
#        [ 60,  61,  61, ..., 127, 129, 129]], dtype=uint8)

# %%
image_bgr = cv2.imread(image_data, cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_bgr)

# %%
plt.imshow(image_rgb)
