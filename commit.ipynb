# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# Out:
# total 10
# -rw------- 1 root root 5153 Jul 12 14:00 commit.ipynb
# drwx------ 2 root root 4096 Jul 12 13:35 .ipynb_checkpoints/

# %%
cd OpenCVLab
# Out:
# [Errno 2] No such file or directory: 'OpenCVLab'
# /content/drive/MyDrive/Colab Notebooks/OpenCVLab

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git remote add origin 'https://github.com/star-moon-cloud-k/OpenCVLab'
# Out:
# fatal: remote origin already exists.

# %%
# !git remote add origin 'https://github.com/star-moon-cloud-k/OpenCVLab'

# %%
# !git config --global user.email 'kspecial44@gmail.com'
# !git config --global user.name 'star_moon_cloud_k'

# %%
# !git commit -m "first commit"
# Out:
# fatal: this operation must be run in a work tree

# %%
# !git push --set-upstream origin main
# Out:
# fatal: 'git@github.com/star-moon-cloud-k/OpenCVLab' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
